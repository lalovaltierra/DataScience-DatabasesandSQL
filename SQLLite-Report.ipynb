# %% [markdown]
# ## Understand the datasets
#
# To complete the assignment problems in this notebook you will be using three datasets that are available on the city of Chicago's Data Portal:
#
# 1.  <a href="https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Socioeconomic Indicators in Chicago</a>
# 2.  <a href="https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Public Schools</a>
# 3.  <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Crime Data</a>
#
# ### 1. Socioeconomic Indicators in Chicago
#
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
#
# [https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2](https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 2. Chicago Public Schools
#
# This dataset shows all school level performance data used to create CPS School Report Cards for the 2011-2012 school year. This dataset is provided by the city of Chicago's Data Portal.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
#
# [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 3. Chicago Crime Data
#
# This dataset reflects reported incidents of crime (with the exception of murders where data exists for each victim) that occurred in the City of Chicago from 2001 to present, minus the most recent seven days.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
#
# [https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to have these three tables populated with a subset of the whole datasets.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet.
#
# Use the links below to read the data files using the Pandas library.
#
# * Chicago Census Data
#
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01
#
# * Chicago Public Schools
#
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01
#
# * Chicago Crime Data
#
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01
#
# **NOTE:** Ensure you use the datasets available on the links above instead of directly from the Chicago Data Portal. The versions linked here are subsets of the original datasets and have some of the column names modified to be more database friendly which will make it easier to complete this assignment.

# %% [markdown]
# Execute the below code cell to avoid prettytable default error.

# %%
# !pip install ipython-sql prettytable

import prettytable

prettytable.DEFAULT = 'DEFAULT'
# Out:
# Requirement already satisfied: ipython-sql in /opt/conda/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /opt/conda/lib/python3.11/site-packages (3.12.0)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.11/site-packages (from ipython-sql) (8.22.2)
# Requirement already satisfied: sqlalchemy>=2.0 in /opt/conda/lib/python3.11/site-packages (from ipython-sql) (2.0.30)
# Requirement already satisfied: sqlparse in /opt/conda/lib/python3.11/site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.11/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prettytable) (0.2.13)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (0.6.2)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)

# %% [markdown]
# ### Store the datasets in database tables
#
# To analyze the data using SQL, it first needs to be loaded into SQLite DB.
# We will create three tables in as under:
#
# 1.  **CENSUS_DATA**
# 2.  **CHICAGO_PUBLIC_SCHOOLS**
# 3.  **CHICAGO_CRIME_DATA**

# %% [markdown]
# Load the `pandas` and `sqlite3` libraries and establish a connection to `FinalDB.db`

# %%
# These libraries are pre-installed in SN Labs. If running in another environment please uncomment lines below to install them:
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# Ensure we don't load_ext with sqlalchemy>=1.4 (incompadible)
# !pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
# !pip install ipython-sql
# Out:
# Collecting ibm_db==3.1.0
#   Downloading ibm_db-3.1.0.tar.gz (797 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.3/797.3 kB 30.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ibm_db_sa==0.3.3
#   Downloading ibm_db_sa-0.3.3.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sqlalchemy>=0.7.3 (from ibm_db_sa==0.3.3)
#   Downloading SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy>=0.7.3->ibm_db_sa==0.3.3)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=0.7.3->ibm_db_sa==0.3.3)
#   Downloading greenlet-3.1.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Downloading SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 85.6 MB/s eta 0:00:00:00:01
# Downloading greenlet-3.1.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (602 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.4/602.4 kB 48.2 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Building wheels for collected packages: ibm_db, ibm_db_sa
#   Building wheel for ibm_db (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for ibm_db (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1086 lines of output]
#       Detected 64-bit Python
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-311
#       copying ibm_db_dbi.py -> build/lib.linux-x86_64-cpython-311
#       copying testfunctions.py -> build/lib.linux-x86_64-cpython-311
#       copying tests.py -> build/lib.linux-x86_64-cpython-311
#       creating build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_100_SelectDeleteInsertFieldCount.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_142_BindParamSelectStmtMultipleParams_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_046_FetchTupleMany_05.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_213_FieldDisplaySize_04.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_155_FetchAssocSelect_05.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_147_PrepareWithWrongType.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_createDropDB.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_116_ConnActive.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_6792_FieldTypeRetStrDatetimeTimestamp.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_159_FetchAssocSeveralRows_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_005_ConnBadUserBadPwd.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_141_BindParamSelectStmtMultipleParams_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_140_BindParamSelectStmt.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_060_Tables_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_051_SetAutocommit_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_014_KeysetDrivenCursorNegativeRow.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_151_FetchAssocSelect_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_052_SetAutocommit_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_000_PrepareDb.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_195_InsertRetrieveXMLData_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_240_FieldWidthPosName_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_SPInOutBlob.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_InsertRetrieveDateTimeTypeColumn.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_145_BindRetrieveNoneEmptyString.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_162_FetchBothNestedSelects_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_038_FetchRowIndexPosNested_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_049_InsertNoneParam.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_023_ColumnPrivileges.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_261_FetchObjectAccess.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_220_PersistentConn.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_currentschema.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_047_FetchTupleMany_06.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_trusted_context_pconnect.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_065_FilterTableName.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_042_FetchTupleMany_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_071_CloseSuccess.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_197_StatisticsIndexes.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_159a_FetchAssocSeveralRows_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_120_FieldName.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_execute_many.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_043_FetchTupleMany_03.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_111_FieldNumAddCol.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_044_FetchTupleMany_04.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_025_PrimaryKeys.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_160_FetchBoth.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_264_InsertRetrieveBIGINTTypeColumn.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_020_RollbackDelete.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_121_FieldNameAddCol.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_048_FetchTupleBinaryData_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_011_DeleteRowCount.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_054_CursorType.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_034_FetchAssoc.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_070_Close.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_066_TableObjects.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_015_InsertDeleteRowCount_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_createdbNX.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_090_ConnmsgWrongDbAlias.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_008_ColumnInfo.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_115_NumericTest_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_231_FieldTypeName.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_156_FetchAssocNestedSelects_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_157b_FetchAssocScrollableCursor_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_146_CallSPINAndOUTParams.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_016_InsertDeleteRowCount_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_035_FetchRow_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_045_FetchTupleBinaryData_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_021_CommitDelete.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_148_CallSPDiffBindPattern_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_004_ConnWrongUserPwd.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_082_ConnWrongPwd.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_036_FetchRow_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_131_PrepareExecuteSelectStatementParams.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_113_DateTest.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_265_NoAffectedRows.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_300_ServerInfo.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_158_FetchAssocNestedSelects_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_157_FetchAssocScrollableCursor_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_030_Result.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_150_FetchAssocSelect_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_037_FetchRowIndexPos.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_022_RollbackInsert.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_010_UpdateRowCount.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_091_ConnmsgWrongUser.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_031_ResultIndexPosition.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_114_NumericTest_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_err_executemany.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_102_NumFieldsSelect_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_019_selectRowcountPrefetchPrepOpt.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_130_PrepExecuteSelectStmt.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_124_FieldNamePos_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_125_FieldNamePos_03.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_112_FieldNumDiffCaseColNames.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_032_ResultIndexName.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_201_MultipleRsltsetsDiffColDefs.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_080_ConnWrongDbAlias.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_123_FieldNamePos_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_161_FetchBothNestedSelects_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_190_ColumnsTable_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_230_FieldTypePos.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_061_Tables_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_03a_ResultNonExistCol.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_153_FetchAssocSelect_04.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_cursortype.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_050_AutocommitStatus.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_122_FieldNameDiffCaseColNames.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_144_BindParamInsertStmtPARAM_FILE.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_setgetOption.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_002_ConnDbUncatalogedConn.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_6561_InsertNULLValues.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_310_ClientInfo.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_040_FetchTuple.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_232_FieldTypePosName.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_trusted_context_connect.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_decfloat.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_157a_FetchAssocWithoutScrollableCursorErr.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_bool_callproc.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_booleanInsertSelect.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_132_ExecuteStatementArrayMultipleParams.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_210_FieldDisplaySize_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_6755_ExtraNULLChar_ResultCLOBCol.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_decimal.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_033_ResultOutSequenceColumn.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_024_ForeignKeys.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_recreateDB.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_053_AttrThruConn.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_110_FieldNum.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_191_ColumnsTable_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_062_Tables_03.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_52949_TestSPIntVarcharXml.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_007_pConnPassingOpts.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_221_100PersistentConns.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_180_StmtErrMsg.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_013_KeysetDrivenCursorSelect02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_311_InsertSelectDeleteNumLiterals.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_196_InsertRetrieveXMLData_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_064_Tables_05.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_212_FieldDisplaySize_03.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_018_selectRowcountPrefetchSetOpt.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_006_ConnPassingOpts.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_SPInOutZero.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/__init__.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_081_ConnWrongUser.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_251_FreeResult_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_133_ExecuteLongInputParams.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_211_FieldDisplaySize_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_092_ConnmsgWrongPwd.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_241_FieldWidthPosName_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_012_KeysetDrivenCursorSelect01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_250_FreeResult_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_143_BindParamInsertStmtNoneParam.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_039_FetchRowIndexPosNested_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_260_FetchTupleMany_07.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_063_Tables_04.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_001_ConnDb.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_041_FetchTupleMany_01.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_warn.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_017_selectRowcountPrefetchSTMTOpt.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_6528_ScopingProblemBindParam.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_103_NumFieldsSelect_02.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_003_NumAffectedRows.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_200_MultipleRsltsetsUniformColDefs.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_checkBooleanType.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_152_FetchAssocSelect_03.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_101_InsertDeleteFieldCount.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       copying ibm_db_tests/test_154_AllFetches.py -> build/lib.linux-x86_64-cpython-311/ibm_db_tests
#       creating build/lib.linux-x86_64-cpython-311/certs
#       copying certs/__init__.py -> build/lib.linux-x86_64-cpython-311/certs
#       creating build/lib.linux-x86_64-cpython-311/clidriver
#       copying clidriver/__init__.py -> build/lib.linux-x86_64-cpython-311/clidriver
#       running egg_info
#       writing ibm_db.egg-info/PKG-INFO
#       writing dependency_links to ibm_db.egg-info/dependency_links.txt
#       writing top-level names to ibm_db.egg-info/top_level.txt
#       reading manifest file 'ibm_db.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '*.png' under directory 'ibm_db_tests'
#       warning: no files found matching '*.jpg' under directory 'ibm_db_tests'
#       warning: no files found matching '*' under directory 'ibm_db_dlls'
#       warning: no previously-included files found matching 'config.py'
#       adding license file 'LICENSE'
#       writing manifest file 'ibm_db.egg-info/SOURCES.txt'
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.bin' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.bin' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.bin' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.bin' to be distributed and are
#               already explicitly excluding 'clidriver.bin' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.bnd' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.bnd' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.bnd' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.bnd' to be distributed and are
#               already explicitly excluding 'clidriver.bnd' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.cfg' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.cfg' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.cfg' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.cfg' to be distributed and are
#               already explicitly excluding 'clidriver.cfg' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.cfgcache' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.cfgcache' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.cfgcache' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.cfgcache' to be distributed and are
#               already explicitly excluding 'clidriver.cfgcache' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.conv.alt' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.conv.alt' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.conv.alt' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.conv.alt' to be distributed and are
#               already explicitly excluding 'clidriver.conv.alt' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.conv.ms' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.conv.ms' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.conv.ms' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.conv.ms' to be distributed and are
#               already explicitly excluding 'clidriver.conv.ms' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.db2dump' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.db2dump' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.db2dump' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.db2dump' to be distributed and are
#               already explicitly excluding 'clidriver.db2dump' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.include' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.include' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.include' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.include' to be distributed and are
#               already explicitly excluding 'clidriver.include' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.lib' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.lib' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.lib' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.lib' to be distributed and are
#               already explicitly excluding 'clidriver.lib' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.lib.icc' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.lib.icc' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.lib.icc' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.lib.icc' to be distributed and are
#               already explicitly excluding 'clidriver.lib.icc' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.lib.icc.C.icc.icclib' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.lib.icc.C.icc.icclib' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.lib.icc.C.icc.icclib' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.lib.icc.C.icc.icclib' to be distributed and are
#               already explicitly excluding 'clidriver.lib.icc.C.icc.icclib' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       /tmp/pip-build-env-k3s8drzh/overlay/lib/python3.11/site-packages/setuptools/command/build_py.py:212: _Warning: Package 'clidriver.lib.icc.N.icc.icclib' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.lib.icc.N.icc.icclib' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.lib.icc.N.icc.icclib' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.lib.icc.N.icc.icclib' to be distributed and are
#               already explicitly excluding 'clidriver.lib.icc.N.icc.icclib' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
# ...
#       copying clidriver/conv/ms/0930ucs2.cnv -> build/lib.linux-x86_64-cpython-311/clidriver/conv/ms
#       copying clidriver/conv/ms/0939ucs2.cnv -> build/lib.linux-x86_64-cpython-311/clidriver/conv/ms
#       copying clidriver/conv/ms/0943ucs2.cnv -> build/lib.linux-x86_64-cpython-311/clidriver/conv/ms
#       copying clidriver/conv/ms/0954ucs2.cnv -> build/lib.linux-x86_64-cpython-311/clidriver/conv/ms
#       copying clidriver/conv/ms/1390ucs2.cnv -> build/lib.linux-x86_64-cpython-311/clidriver/conv/ms
#       copying clidriver/conv/ms/1399ucs2.cnv -> build/lib.linux-x86_64-cpython-311/clidriver/conv/ms
#       copying clidriver/conv/ms/5039ucs2.cnv -> build/lib.linux-x86_64-cpython-311/clidriver/conv/ms
#       copying clidriver/conv/ms/ucs20943.cnv -> build/lib.linux-x86_64-cpython-311/clidriver/conv/ms
#       creating build/lib.linux-x86_64-cpython-311/clidriver/db2dump
#       copying clidriver/db2dump/db2diag.log -> build/lib.linux-x86_64-cpython-311/clidriver/db2dump
#       creating build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sql.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sqlca.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sqlcli.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sqlcli1.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sqlda.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sqlenv.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sqlext.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sqlstate.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sqlsystm.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sqltypes.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sqlucode.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       copying clidriver/include/sqlunx.h -> build/lib.linux-x86_64-cpython-311/clidriver/include
#       creating build/lib.linux-x86_64-cpython-311/clidriver/lib
#       copying clidriver/lib/libDB2xml4c.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib
#       copying clidriver/lib/libDB2xml4c.so.58 -> build/lib.linux-x86_64-cpython-311/clidriver/lib
#       copying clidriver/lib/libDB2xml4c.so.58.0 -> build/lib.linux-x86_64-cpython-311/clidriver/lib
#       copying clidriver/lib/libdb2.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib
#       copying clidriver/lib/libdb2.so.1 -> build/lib.linux-x86_64-cpython-311/clidriver/lib
#       copying clidriver/lib/libdb2clixml4c.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib
#       copying clidriver/lib/libdb2clixml4c.so.1 -> build/lib.linux-x86_64-cpython-311/clidriver/lib
#       creating build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8acmeidup_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8cms_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8dbfl_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8drld_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8iccs_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8kicc_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8km2_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8km_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8ldap_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8p11_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8ssl_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8sys_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       copying clidriver/lib/icc/libgsk8valn_64.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc
#       creating build/lib.linux-x86_64-cpython-311/clidriver/lib/icc/C/icc/icclib
#       copying clidriver/lib/icc/C/icc/icclib/ICCSIG.txt -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc/C/icc/icclib
#       copying clidriver/lib/icc/C/icc/icclib/libicclib084.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc/C/icc/icclib
#       creating build/lib.linux-x86_64-cpython-311/clidriver/lib/icc/N/icc/icclib
#       copying clidriver/lib/icc/N/icc/icclib/ICCSIG.txt -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc/N/icc/icclib
#       copying clidriver/lib/icc/N/icc/icclib/libicclib085.so -> build/lib.linux-x86_64-cpython-311/clidriver/lib/icc/N/icc/icclib
#       creating build/lib.linux-x86_64-cpython-311/clidriver/license
#       copying clidriver/license/odbc_REDIST.txt -> build/lib.linux-x86_64-cpython-311/clidriver/license
#       copying clidriver/license/odbc_notices.txt -> build/lib.linux-x86_64-cpython-311/clidriver/license
#       creating build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_cs -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_de -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_el -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_en -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_es -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_fr -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_in -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_it -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_ja -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_ko -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_lt -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_pl -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_pt -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_ru -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_sl -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_tr -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_zh -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       copying clidriver/license/UNIX/odbc_LI_zh_TW -> build/lib.linux-x86_64-cpython-311/clidriver/license/UNIX
#       creating build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2adm.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2admh.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2caem.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2cklog.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2cli.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2clia1.lst -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2clias.lst -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2clih.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2clit.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2clp.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2clp2.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2diag.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2fodc.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2sql.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2sqlh.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2stt.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       copying clidriver/msg/en_US.iso88591/db2supp.mo -> build/lib.linux-x86_64-cpython-311/clidriver/msg/en_US.iso88591
#       creating build/lib.linux-x86_64-cpython-311/clidriver/properties/version
#       copying clidriver/properties/version/ibm.com_IBM_Data_Server_Driver_for_ODBC_and_CLI-11.5.0.swidtag -> build/lib.linux-x86_64-cpython-311/clidriver/properties/version
#       creating build/lib.linux-x86_64-cpython-311/clidriver/scripts
#       copying clidriver/scripts/setenv.sh -> build/lib.linux-x86_64-cpython-311/clidriver/scripts
#       copying clidriver/scripts/testconnection.sh -> build/lib.linux-x86_64-cpython-311/clidriver/scripts
#       creating build/lib.linux-x86_64-cpython-311/clidriver/security64/plugin/IBM/client
#       copying clidriver/security64/plugin/IBM/client/IBMIAMauth.so -> build/lib.linux-x86_64-cpython-311/clidriver/security64/plugin/IBM/client
#       copying clidriver/security64/plugin/IBM/client/IBMkrb5.so -> build/lib.linux-x86_64-cpython-311/clidriver/security64/plugin/IBM/client
#       running build_ext
#       building 'ibm_db' extension
#       creating build/temp.linux-x86_64-cpython-311
#       gcc -pthread -B /opt/conda/compiler_compat -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC -Iclidriver/include -I/opt/conda/include/python3.11 -c ibm_db.c -o build/temp.linux-x86_64-cpython-311/ibm_db.o
#       error: command 'gcc' failed: No such file or directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for ibm_db
#   Building wheel for ibm_db_sa (setup.py) ... done
#   Created wheel for ibm_db_sa: filename=ibm_db_sa-0.3.3-py3-none-any.whl size=27421 sha256=5a8b79bcf64dbcc494fa6c412615f7107db87af51c48c8cae2944df194450ffa
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/cb/af/47/1cdbd4797d6c6cbc611c5aa48a53df475cb46fe8b0d3856193
# Successfully built ibm_db_sa
# Failed to build ibm_db
# ERROR: Could not build wheels for ibm_db, which is required to install pyproject.toml-based projects
# Found existing installation: SQLAlchemy 2.0.30
# Uninstalling SQLAlchemy-2.0.30:
#   Successfully uninstalled SQLAlchemy-2.0.30
# Collecting sqlalchemy==1.3.24
#   Downloading SQLAlchemy-1.3.24.tar.gz (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 87.7 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py) ... done
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.24-cp311-cp311-linux_x86_64.whl size=1203249 sha256=ac44d6c757b0b3d3d57d6fa6493e48f4cc2ef986d1c13e0b6fa4342c087336ce
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/27/e3/c5/7ba1f3cf983a93b35c849e97fd51a82aa7adf440641a2f690b
# Successfully built sqlalchemy
# Installing collected packages: sqlalchemy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.24 which is incompatible.
# jupyterhub 5.2.1 requires SQLAlchemy>=1.4.1, but you have sqlalchemy 1.3.24 which is incompatible.
# Successfully installed sqlalchemy-1.3.24
# Requirement already satisfied: ipython-sql in /opt/conda/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /opt/conda/lib/python3.11/site-packages (from ipython-sql) (3.12.0)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.11/site-packages (from ipython-sql) (8.22.2)
# Collecting sqlalchemy>=2.0 (from ipython-sql)
#   Using cached SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: sqlparse in /opt/conda/lib/python3.11/site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.11/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (0.6.2)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Using cached SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.24
#     Uninstalling SQLAlchemy-1.3.24:
#       Successfully uninstalled SQLAlchemy-1.3.24
# Successfully installed sqlalchemy-2.0.36

# %% [markdown]
# Load the SQL magic module

# %%
# %load_ext sql

# %% [markdown]
# Use `Pandas` to load the data available in the links above to dataframes. Use these dataframes to load data on to the database `FinalDB.db` as required tables.

# %%
#!pip install -q pandas==1.1.5
import csv, sqlite3

con = sqlite3.connect("FinalDB.db")
cur = con.cursor()
import pandas
df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df.to_sql("CENSUS_DATA", con, if_exists='replace', index=False,method="multi")

df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df.to_sql("CHICAGO_CRIME_DATA", con, if_exists='replace', index=False, method="multi")

df = pandas.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01")
df.to_sql("CHICAGO_PUBLIC_SCHOOLS_DATA", con, if_exists='replace', index=False, method="multi")
# Out:
# 566

# %% [markdown]
# Establish a connection between SQL magic module and the database `FinalDB.db`

# %%
# %sql sqlite:///FinalDB.db

# %% [markdown]
# You can now proceed to the the following questions. Please note that a graded assignment will follow this lab and there will be a question on each of the problems stated below. It can be from the answer you received or the code you write for this problem. Therefore, please keep a note of both your codes as well as the response you generate.

# %% [markdown]
# ## Problems
#
# Now write and execute SQL queries to solve assignment problems
#
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %sql select count(*) from CHICAGO_CRIME_DATA;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(533,)]

# %% [markdown]
# ### Problem 2
#
# ##### List community area names and numbers with per capita income less than 11000.

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM CENSUS_DATA WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('West Garfield Park',),
#  ('South Lawndale',),
#  ('Fuller Park',),
#  ('Riverdale',)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %sql SELECT DISTINCT CASE_NUMBER FROM CHICAGO_CRIME_DATA WHERE DESCRIPTION LIKE '%MINOR%'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('HL266884',), ('HK238408',)]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %sql SELECT DISTINCT CASE_NUMBER, PRIMARY_TYPE, DATE, DESCRIPTION FROM CHICAGO_CRIME_DATA \
WHERE PRIMARY_TYPE='KIDNAPPING'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('HN144152', 'KIDNAPPING', '2007-01-26', 'CHILD ABDUCTION/STRANGER')]

# %% [markdown]
# ### Problem 5
#
# ##### List the kind of crimes that were recorded at schools. (No repetitions)

# %%
# %sql SELECT DISTINCT(PRIMARY_TYPE), LOCATION_DESCRIPTION FROM CHICAGO_CRIME_DATA \
WHERE LOCATION_DESCRIPTION LIKE '%SCHOOL%'
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('BATTERY', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('BATTERY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('CRIMINAL DAMAGE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, BUILDING'),
#  ('ASSAULT', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL TRESPASS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PRIVATE, BUILDING'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PUBLIC, BUILDING')]

# %% [markdown]
# ### Problem 6
#
# ##### List the type of schools along with the average safety score for each type.

# %%
# %sql SELECT "Elementary, Middle, or High School", AVG(SAFETY_SCORE) AVERAGE_SAFETY_SCORE FROM CHICAGO_PUBLIC_SCHOOLS GROUP BY "Elementary, Middle, or High School";
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) no such table: CHICAGO_PUBLIC_SCHOOLS
# [SQL: SELECT "Elementary, Middle, or High School" , AVG(SAFETY_SCORE) AVERAGE_SAFETY_SCORE FROM CHICAGO_PUBLIC_SCHOOLS GROUP BY "Elementary, Middle, or High School" ;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %sql SELECT COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY FROM CENSUS_DATA ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC LIMIT 5 ;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %% [markdown]
# ### Problem 8
#
# ##### Which community area is most crime prone? Display the coumminty area number only.

# %%
# %%sql
# SELECT COMMUNITY_AREA_NUMBER ,COUNT(COMMUNITY_AREA_NUMBER) AS FREQUENCY
# FROM CHICAGO_CRIME_DATA
# GROUP BY COMMUNITY_AREA_NUMBER
# ORDER BY COUNT(COMMUNITY_AREA_NUMBER) DESC
# LIMIT 1;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(25.0, 43)]

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM  CENSUS_DATA WHERE HARDSHIP_INDEX = (SELECT MAX(HARDSHIP_INDEX) FROM CENSUS_DATA);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale',)]

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %%sql
# SELECT community_area_name FROM CENSUS_DATA
# WHERE COMMUNITY_AREA_NUMBER = (SELECT COMMUNITY_AREA_NUMBER FROM CHICAGO_CRIME_DATA
#     GROUP BY COMMUNITY_AREA_NUMBER
#     ORDER BY COUNT(COMMUNITY_AREA_NUMBER) DESC
#     LIMIT 1)
# LIMIT 1;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Austin',)]
